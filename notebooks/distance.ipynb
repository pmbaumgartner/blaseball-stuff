# %%
import pandas as pd
import altair as alt
import statsmodels.formula.api as smf

# %%
# Player Attributes Sheet from https://docs.google.com/spreadsheets/d/1CnPsdnZc4lFObYpu6R5lEYzRLmIBh-I03JFsTX6AaXE/edit#gid=108546025
# fielding data from SIBR discord
# players from Geography Google Drive (SIBR Discord)

fielding_raw = pd.read_csv("../data/fielding-thru-game-72.csv").assign(
    fielder=lambda d: d["fielder"]
    .str.replace("&#x27;", "'")
    .str.replace("Jr", "Jr.")
    .str.replace("al-", "Al-")
    .str.replace("O'c", "O'C")
)

attributes_raw = pd.read_csv(
    "../data/Player Attributes Sheet - All Players.csv", header=1
)
# last 13 rows are aggregates
attributes_raw = attributes_raw.drop(attributes_raw.tail(13).index, axis="rows")
# pitchers don't field
attributes_raw = attributes_raw.query("Position != 'Pitcher'")

players = pd.read_csv("../data/players.csv").rename(columns={"Player": "Name"})

# %%
dtypes = {
    "Rating": float,
    "sight": float,
    "thwack": float,
    "fero": float,
    "Batting": float,
    "control": float,
    "stuff": float,
    "guile": float,
    "Pitching": float,
    "reach": float,
    "magnet": float,
    "reflex": float,
    "Defense": float,
    "hustle": float,
    "stealth": float,
    "dodge": float,
    "Running": float,
    "thrive": float,
    "survive": float,
    "drama": float,
    "Vibes": float,
}

attributes_raw = attributes_raw.astype(dtypes)

# %%
hit_against_fielder_loc = (
    fielding_raw.groupby(["fielder", "hit_loc"])["hit"].sum().to_frame()
)

# %%
centroids = {
    "The Wall": (5, 5),
    "Right Field": (4, 1),
    "Left Field": (1, 4),
    "Deep Center Field": (5, 5),
    "Center Field": (4, 4),
    "Infield": (1, 1),
    "Deep Right Field": (5, 1),
    "into play": None,
    "Deep Left Field": (1, 5),
}

# %%
fielding_locs = fielding_raw.rename(columns={"fielder": "Name"}).merge(
    players, on="Name"
)
fielding_locs = fielding_locs[fielding_locs["hit_loc"] != "into play"]
fielding_locs["centroid"] = fielding_locs["hit_loc"].map(centroids)


def distance_manhattan(row):
    return abs(row["X"] - row["centroid"][0]) + abs(row["Y"] - row["centroid"][1])


def distance_euclidean(row):
    return (
        (row["X"] - row["centroid"][0]) ** 2 + (row["Y"] - row["centroid"][1]) ** 2
    ) ** 0.5


fielding_locs["play_dist manhattan"] = fielding_locs.apply(distance_manhattan, axis=1)
fielding_locs["play_dist euclidean"] = fielding_locs.apply(distance_euclidean, axis=1)

# %%
weird_fielding_locs = fielding_locs.apply(
    lambda d: (d["X"] in [3, 4]) and (d["Y"] == 0) and (d["hit_loc"] == "Left Field"),
    axis=1,
)

# %%
hit_by_distance_both = (
    fielding_locs[~weird_fielding_locs]
    .groupby(["play_dist manhattan", "play_dist euclidean"])["hit"]
    .sum()
    / fielding_locs[~weird_fielding_locs]
    .groupby(["play_dist manhattan", "play_dist euclidean"])["hit"]
    .size()
)
hit_by_distance_both = hit_by_distance_both.to_frame()
hit_by_distance_both["count_hits"] = (
    fielding_locs[~weird_fielding_locs]
    .groupby(["play_dist manhattan", "play_dist euclidean"])["hit"]
    .sum()
)
hit_by_distance_both["count_total"] = (
    fielding_locs[~weird_fielding_locs]
    .groupby(["play_dist manhattan", "play_dist euclidean"])["hit"]
    .size()
)
print("Euclidean vs. Manhattan Distance Comparison")
print(hit_by_distance_both.reset_index().round(2))
# Out:
# Euclidean vs. Manhattan Distance Comparison
#     play_dist manhattan  play_dist euclidean   hit  count_hits  count_total
# 0                     0                 0.00  0.20         589         2965
# 1                     1                 1.00  0.20        1840         9121
# 2                     2                 1.41  0.23        1419         6262
# 3                     2                 2.00  0.26         681         2577
# 4                     3                 2.24  0.30        1222         4043
# 5                     3                 3.00  0.32         649         2036
# 6                     4                 2.83  0.31         283          914
# 7                     4                 3.16  0.31         919         2950
# 8                     4                 4.00  0.31         399         1271
# 9                     5                 3.61  0.33         389         1191
# 10                    5                 4.12  0.33         593         1795
# 11                    5                 5.00  0.28          83          300
# 12                    6                 4.24  0.33         174          520
# 13                    6                 4.47  0.35         288          817
# 14                    6                 5.10  0.35          93          263
# 15                    7                 5.00  0.33         320          976
# 16                    7                 5.39  0.42          76          179
# 17                    8                 5.66  0.36         133          368
# 18                    8                 5.83  0.45          40           88
# 19                    9                 6.40  0.38          44          115
# 20                   10                 7.07  0.39           7           18

# %%
hbd_all = pd.DataFrame()
hit_by_distance_all = (
    fielding_locs.groupby(["play_dist manhattan"])["hit"].sum()
    / fielding_locs.groupby(["play_dist manhattan"])["hit"].size()
)
hbd_all["manhattan_hit"] = hit_by_distance_all

hit_by_distance_all_no_weirds = (
    fielding_locs[~weird_fielding_locs].groupby(["play_dist manhattan"])["hit"].sum()
    / fielding_locs[~weird_fielding_locs].groupby(["play_dist manhattan"])["hit"].size()
)
hbd_all["manhattan_no_weirds_hit"] = hit_by_distance_all_no_weirds
hbd_all = (
    hbd_all.unstack(level=1)
    .reset_index()
    .rename(columns={"level_0": "dataset", 0: "hit %"})
)
hbd_all
# Out:
#                     dataset  play_dist manhattan     hit %
# 0             manhattan_hit                    0  0.198651
# 1             manhattan_hit                    1  0.201732
# 2             manhattan_hit                    2  0.237583
# 3             manhattan_hit                    3  0.307781
# 4             manhattan_hit                    4  0.311782
# 5             manhattan_hit                    5  0.324102
# 6             manhattan_hit                    6  0.304172
# 7             manhattan_hit                    7  0.273429
# 8             manhattan_hit                    8  0.379386
# 9             manhattan_hit                    9  0.382609
# 10            manhattan_hit                   10  0.388889
# 11  manhattan_no_weirds_hit                    0  0.198651
# 12  manhattan_no_weirds_hit                    1  0.201732
# 13  manhattan_no_weirds_hit                    2  0.237583
# 14  manhattan_no_weirds_hit                    3  0.307781
# 15  manhattan_no_weirds_hit                    4  0.311782
# 16  manhattan_no_weirds_hit                    5  0.324102
# 17  manhattan_no_weirds_hit                    6  0.346875
# 18  manhattan_no_weirds_hit                    7  0.342857
# 19  manhattan_no_weirds_hit                    8  0.379386
# 20  manhattan_no_weirds_hit                    9  0.382609
# 21  manhattan_no_weirds_hit                   10  0.388889

# %%
c1 = (
    alt.Chart(hbd_all, title="% Hit by Play Distance")
    .mark_circle()
    .encode(x="play_dist manhattan", y="hit %", color="dataset")
)
display(c1)
# Out:
# /Users/peter/miniconda3/envs/blaseball-stuff/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
hit_by_distance_loc = (
    fielding_locs.groupby(["hit_loc", "play_dist manhattan"])["hit"].sum()
    / fielding_locs.groupby(["hit_loc", "play_dist manhattan"])["hit"].size()
)
hit_by_distance_loc.to_frame().reset_index().tail(20)
# Out:
#         hit_loc  play_dist manhattan       hit
# 58  Right Field                    0  0.178182
# 59  Right Field                    1  0.201268
# 60  Right Field                    2  0.247810
# 61  Right Field                    3  0.323359
# 62  Right Field                    4  0.294201
# 63  Right Field                    5  0.321534
# 64  Right Field                    6  0.428571
# 65  Right Field                    7  0.310811
# 66  Right Field                    8  0.258621
# 67     The Wall                    0  0.194805
# 68     The Wall                    1  0.245399
# 69     The Wall                    2  0.258290
# 70     The Wall                    3  0.269634
# 71     The Wall                    4  0.344898
# 72     The Wall                    5  0.279279
# 73     The Wall                    6  0.367412
# 74     The Wall                    7  0.396825
# 75     The Wall                    8  0.472000
# 76     The Wall                    9  0.352113
# 77     The Wall                   10  0.400000

# %%
hbd_loc = hit_by_distance_loc.to_frame().reset_index()

# %%
alt.Chart(hbd_loc, title=r"Hit % by play_distance").mark_circle().encode(
    x="play_dist manhattan", y="hit", color="hit_loc"
)
# Out:
# /Users/peter/miniconda3/envs/blaseball-stuff/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# ## Regression town
#
# Let's figure out the relationship between play distance and any relevant player attributes.
#
# **We are going to use the fielding data _without_ the weird fielding locations.**

# %%
print("N Fielding Records", len(fielding_locs))
print("N Fielding Records (No Weird)", len(fielding_locs[~weird_fielding_locs]))
# Out:
# N Fielding Records 40057
# N Fielding Records (No Weird) 38769

# %%
attributes_with_fielding = (
    fielding_locs[~weird_fielding_locs]
    .merge(attributes_raw, on="Name")
    .rename(columns={"play_dist manhattan": "play_dist"})
)

# %%
player_attributes = [
    "sight",
    "thwack",
    "fero",
    "control",
    "stuff",
    "guile",
    "reach",
    "magnet",
    "reflex",
    "hustle",
    "stealth",
    "dodge",
    "thrive",
    "survive",
    "drama",
]

# %%
model_stats = []
for attr in player_attributes:
    l = smf.logit(
        formula=f"hit ~ play_dist*{attr}", data=attributes_with_fielding
    ).fit()
    print("---", attr, "---")
    print(l.summary2())
    model_stats.append(
        {
            "attr": attr,
            "aic": l.aic,
            "bic": l.bic,
            "prsquared": l.prsquared,
            "pval_interaction": l.pvalues[f"play_dist:{attr}"],
        }
    )
# Out:
# Optimization terminated successfully.
#          Current function value: 0.570754
#          Iterations 5
# --- sight ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43840.7954
# Date:               2023-01-15 14:18 BIC:              43875.0186
# No. Observations:   38399            Log-Likelihood:   -21916.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      3.9026e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.3771   0.0479 -28.7485 0.0000 -1.4710 -1.2832
# play_dist          0.1247   0.0133   9.3884 0.0000  0.0986  0.1507
# sight             -0.0598   0.0771  -0.7749 0.4384 -0.2110  0.0914
# play_dist:sight    0.0247   0.0218   1.1298 0.2585 -0.0181  0.0674
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570646
#          Iterations 5
# --- thwack ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43832.4656
# Date:               2023-01-15 14:18 BIC:              43866.6888
# No. Observations:   38399            Log-Likelihood:   -21912.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      6.1095e-114
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.5478   0.0505 -30.6518 0.0000 -1.6468 -1.4489
# play_dist          0.1661   0.0146  11.4150 0.0000  0.1376  0.1947
# thwack             0.2413   0.0795   3.0367 0.0024  0.0856  0.3971
# play_dist:thwack  -0.0487   0.0227  -2.1478 0.0317 -0.0932 -0.0043
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570706
#          Iterations 5
# --- fero ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43837.0645
# Date:               2023-01-15 14:18 BIC:              43871.2877
# No. Observations:   38399            Log-Likelihood:   -21915.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      6.0638e-113
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.3804   0.0489 -28.2147 0.0000 -1.4763 -1.2845
# play_dist          0.1480   0.0147  10.1017 0.0000  0.1193  0.1767
# fero              -0.0519   0.0773  -0.6711 0.5022 -0.2033  0.0996
# play_dist:fero    -0.0159   0.0228  -0.6959 0.4865 -0.0606  0.0288
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570722
#          Iterations 5
# --- control ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43838.3222
# Date:               2023-01-15 14:18 BIC:              43872.5454
# No. Observations:   38399            Log-Likelihood:   -21915.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      1.1359e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4268   0.0400 -35.6356 0.0000 -1.5052 -1.3483
# play_dist          0.1322   0.0113  11.7293 0.0000  0.1101  0.1543
# control            0.0340   0.0707   0.4817 0.6300 -0.1045  0.1726
# play_dist:control  0.0128   0.0201   0.6336 0.5263 -0.0267  0.0522
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570732
#          Iterations 5
# --- stuff ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43839.0993
# Date:               2023-01-15 14:18 BIC:              43873.3225
# No. Observations:   38399            Log-Likelihood:   -21916.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      1.6740e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4488   0.0400 -36.2428 0.0000 -1.5272 -1.3705
# play_dist          0.1403   0.0119  11.8272 0.0000  0.1171  0.1636
# stuff              0.0873   0.0730   1.1951 0.2320 -0.0558  0.2304
# play_dist:stuff   -0.0062   0.0210  -0.2955 0.7676 -0.0474  0.0350
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570338
#          Iterations 5
# --- guile ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43808.8510
# Date:               2023-01-15 14:18 BIC:              43843.0741
# No. Observations:   38399            Log-Likelihood:   -21900.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      4.6520e-119
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.3191   0.0361 -36.5466 0.0000 -1.3899 -1.2484
# play_dist          0.1391   0.0103  13.4390 0.0000  0.1188  0.1594
# guile             -0.2020   0.0664  -3.0394 0.0024 -0.3322 -0.0717
# play_dist:guile   -0.0036   0.0191  -0.1889 0.8502 -0.0411  0.0339
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570534
#          Iterations 5
# --- reach ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43823.8675
# Date:               2023-01-15 14:18 BIC:              43858.0906
# No. Observations:   38399            Log-Likelihood:   -21908.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      8.3646e-116
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.5408   0.0492 -31.3279 0.0000 -1.6372 -1.4444
# play_dist          0.1950   0.0149  13.0672 0.0000  0.1658  0.2242
# reach              0.2138   0.0753   2.8412 0.0045  0.0663  0.3614
# play_dist:reach   -0.0910   0.0220  -4.1390 0.0000 -0.1342 -0.0479
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.561644
#          Iterations 5
# --- magnet ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.027
# Dependent Variable: hit              AIC:              43141.1217
# Date:               2023-01-15 14:18 BIC:              43175.3449
# No. Observations:   38399            Log-Likelihood:   -21567.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      6.9833e-264
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -0.9805   0.0408 -24.0357 0.0000 -1.0605 -0.9006
# play_dist          0.1723   0.0121  14.2700 0.0000  0.1486  0.1960
# magnet            -0.8754   0.0738 -11.8671 0.0000 -1.0200 -0.7308
# play_dist:magnet  -0.0650   0.0217  -2.9971 0.0027 -0.1075 -0.0225
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570685
#          Iterations 5
# --- reflex ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43835.4842
# Date:               2023-01-15 14:18 BIC:              43869.7073
# No. Observations:   38399            Log-Likelihood:   -21914.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      2.7557e-113
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4914   0.0426 -35.0474 0.0000 -1.5748 -1.4080
# play_dist          0.1656   0.0123  13.4688 0.0000  0.1415  0.1897
# reflex             0.1537   0.0693   2.2177 0.0266  0.0179  0.2896
# play_dist:reflex  -0.0522   0.0202  -2.5806 0.0099 -0.0919 -0.0126
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570612
#          Iterations 5
# --- hustle ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43829.8652
# Date:               2023-01-15 14:18 BIC:              43864.0884
# No. Observations:   38399            Log-Likelihood:   -21911.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      1.6688e-114
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.5102   0.0490 -30.8371 0.0000 -1.6062 -1.4142
# play_dist          0.1432   0.0139  10.3007 0.0000  0.1160  0.1704
# hustle             0.1807   0.0793   2.2785 0.0227  0.0253  0.3361
# play_dist:hustle  -0.0097   0.0225  -0.4312 0.6664 -0.0538  0.0344
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570689
#          Iterations 5
# --- stealth ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43835.7519
# Date:               2023-01-15 14:18 BIC:              43869.9751
# No. Observations:   38399            Log-Likelihood:   -21914.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      3.1497e-113
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4400   0.0429 -33.5829 0.0000 -1.5241 -1.3560
# play_dist          0.1314   0.0123  10.6991 0.0000  0.1073  0.1555
# stealth            0.0627   0.0786   0.7976 0.4251 -0.0913  0.2167
# play_dist:stealth  0.0146   0.0228   0.6413 0.5213 -0.0300  0.0592
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570738
#          Iterations 5
# --- dodge ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43839.5169
# Date:               2023-01-15 14:18 BIC:              43873.7401
# No. Observations:   38399            Log-Likelihood:   -21916.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      2.0619e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4425   0.0445 -32.4027 0.0000 -1.5297 -1.3552
# play_dist          0.1548   0.0129  12.0290 0.0000  0.1295  0.1800
# dodge              0.0592   0.0706   0.8385 0.4017 -0.0792  0.1977
# play_dist:dodge   -0.0302   0.0204  -1.4766 0.1398 -0.0702  0.0099
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570769
#          Iterations 5
# --- thrive ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43841.9059
# Date:               2023-01-15 14:18 BIC:              43876.1290
# No. Observations:   38399            Log-Likelihood:   -21917.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      6.7924e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4122   0.0438 -32.2062 0.0000 -1.4982 -1.3263
# play_dist          0.1356   0.0127  10.6394 0.0000  0.1106  0.1606
# thrive             0.0057   0.0751   0.0760 0.9394 -0.1415  0.1529
# play_dist:thrive   0.0045   0.0216   0.2092 0.8343 -0.0379  0.0469
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570772
#          Iterations 5
# --- survive ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43842.1546
# Date:               2023-01-15 14:18 BIC:              43876.3778
# No. Observations:   38399            Log-Likelihood:   -21917.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      7.6902e-112
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4085   0.0437 -32.2441 0.0000 -1.4941 -1.3229
# play_dist          0.1372   0.0127  10.8269 0.0000  0.1124  0.1620
# survive           -0.0023   0.0769  -0.0299 0.9762 -0.1530  0.1484
# play_dist:survive  0.0015   0.0222   0.0659 0.9475 -0.0420  0.0449
# ==================================================================
#
# Optimization terminated successfully.
#          Current function value: 0.570497
#          Iterations 5
# --- drama ---
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: hit              AIC:              43820.9937
# Date:               2023-01-15 14:18 BIC:              43855.2169
# No. Observations:   38399            Log-Likelihood:   -21906.
# Df Model:           3                LL-Null:          -22176.
# Df Residuals:       38395            LLR p-value:      1.9933e-116
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.4412   0.0397 -36.2783 0.0000 -1.5191 -1.3633
# play_dist          0.1213   0.0114  10.6380 0.0000  0.0990  0.1437
# drama              0.0583   0.0727   0.8019 0.4226 -0.0842  0.2009
# play_dist:drama    0.0393   0.0216   1.8194 0.0689 -0.0030  0.0816
# ==================================================================

# %%
pd.DataFrame(model_stats).sort_values("pval_interaction")
# Out:
#        attr           aic           bic  prsquared  pval_interaction
# 6     reach  43823.867493  43858.090640   0.012080          0.000035
# 7    magnet  43141.121729  43175.344875   0.027474          0.002726
# 8    reflex  43835.484182  43869.707329   0.011819          0.009863
# 1    thwack  43832.465606  43866.688753   0.011887          0.031729
# 14    drama  43820.993711  43855.216857   0.012145          0.068851
# 11    dodge  43839.516933  43873.740080   0.011728          0.139791
# 0     sight  43840.795439  43875.018585   0.011699          0.258548
# 2      fero  43837.064509  43871.287656   0.011783          0.486470
# 10  stealth  43835.751936  43869.975083   0.011812          0.521318
# 3   control  43838.322242  43872.545388   0.011755          0.526349
# 9    hustle  43829.865234  43864.088380   0.011945          0.666354
# 4     stuff  43839.099347  43873.322493   0.011737          0.767639
# 12   thrive  43841.905884  43876.129031   0.011674          0.834272
# 5     guile  43808.850999  43843.074146   0.012419          0.850152
# 13  survive  43842.154639  43876.377786   0.011668          0.947456

# %% [markdown]
# **UGH, all the defensive stats have significant interactive terms (and `thwack`). Are they all important?**

# %%
model = [f"play_dist*{var}" for var in player_attributes]
model_str = " + ".join(model)

# %%
l = smf.logit(formula=f"hit ~ {model_str}", data=attributes_with_fielding).fit()
print(l.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.560817
#          Iterations 5
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.029
# Dependent Variable: hit              AIC:              43133.5946
# Date:               2023-01-15 14:18 BIC:              43407.3798
# No. Observations:   38399            Log-Likelihood:   -21535.
# Df Model:           31               LL-Null:          -22176.
# Df Residuals:       38367            LLR p-value:      6.1507e-250
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.1239   0.1529  -7.3481 0.0000 -1.4236 -0.8241
# play_dist          0.2343   0.0453   5.1729 0.0000  0.1455  0.3231
# sight             -0.1317   0.0814  -1.6167 0.1059 -0.2913  0.0280
# play_dist:sight    0.0402   0.0230   1.7471 0.0806 -0.0049  0.0853
# thwack             0.0922   0.0869   1.0610 0.2887 -0.0781  0.2625
# play_dist:thwack  -0.0323   0.0246  -1.3152 0.1884 -0.0804  0.0158
# fero              -0.1151   0.0816  -1.4098 0.1586 -0.2750  0.0449
# play_dist:fero     0.0107   0.0243   0.4410 0.6592 -0.0369  0.0583
# control           -0.1191   0.0794  -1.5009 0.1334 -0.2747  0.0364
# play_dist:control  0.0084   0.0231   0.3622 0.7172 -0.0368  0.0535
# stuff             -0.0098   0.0789  -0.1249 0.9006 -0.1644  0.1447
# play_dist:stuff   -0.0037   0.0232  -0.1600 0.8729 -0.0491  0.0417
# guile             -0.1074   0.0722  -1.4879 0.1368 -0.2489  0.0341
# play_dist:guile    0.0063   0.0209   0.3021 0.7626 -0.0347  0.0473
# reach              0.2747   0.0791   3.4729 0.0005  0.1197  0.4297
# play_dist:reach   -0.0905   0.0231  -3.9182 0.0001 -0.1358 -0.0452
# magnet            -0.9039   0.0770 -11.7399 0.0000 -1.0548 -0.7530
# play_dist:magnet  -0.0549   0.0227  -2.4216 0.0155 -0.0993 -0.0105
# reflex             0.2480   0.0734   3.3804 0.0007  0.1042  0.3917
# play_dist:reflex  -0.0682   0.0215  -3.1659 0.0015 -0.1104 -0.0260
# hustle             0.0693   0.0896   0.7730 0.4395 -0.1063  0.2448
# play_dist:hustle   0.0100   0.0257   0.3889 0.6974 -0.0404  0.0604
# stealth           -0.0070   0.0855  -0.0816 0.9349 -0.1746  0.1606
# play_dist:stealth  0.0093   0.0249   0.3742 0.7083 -0.0395  0.0581
# dodge             -0.0498   0.0754  -0.6605 0.5089 -0.1976  0.0980
# play_dist:dodge   -0.0167   0.0219  -0.7603 0.4471 -0.0596  0.0263
# thrive            -0.0269   0.0814  -0.3301 0.7413 -0.1865  0.1327
# play_dist:thrive   0.0053   0.0235   0.2255 0.8216 -0.0408  0.0515
# survive            0.0993   0.0822   1.2073 0.2273 -0.0619  0.2605
# play_dist:survive -0.0040   0.0239  -0.1675 0.8670 -0.0508  0.0428
# drama              0.0226   0.0778   0.2902 0.7716 -0.1300  0.1752
# play_dist:drama    0.0225   0.0232   0.9717 0.3312 -0.0229  0.0680
# ==================================================================

# %% [markdown]
# All the defense stats are important and have significant interaction terms! Let's model with only them to reduce the noise of the full model and see how that model compares.

# %%
l = smf.logit(
    formula=f"hit ~ play_dist*reach + play_dist*magnet + play_dist*reflex",
    data=attributes_with_fielding,
).fit()
print(l.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.561313
#          Iterations 5
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.028
# Dependent Variable: hit              AIC:              43123.6938
# Date:               2023-01-15 14:18 BIC:              43192.1401
# No. Observations:   38399            Log-Likelihood:   -21554.
# Df Model:           7                LL-Null:          -22176.
# Df Residuals:       38391            LLR p-value:      2.1971e-264
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# Intercept         -1.2464   0.0718 -17.3651 0.0000 -1.3871 -1.1057
# play_dist          0.2600   0.0215  12.1170 0.0000  0.2179  0.3021
# reach              0.2519   0.0760   3.3156 0.0009  0.1030  0.4008
# play_dist:reach   -0.0874   0.0223  -3.9235 0.0001 -0.1310 -0.0437
# magnet            -0.8880   0.0738 -12.0326 0.0000 -1.0327 -0.7434
# play_dist:magnet  -0.0611   0.0217  -2.8193 0.0048 -0.1037 -0.0186
# reflex             0.2267   0.0697   3.2508 0.0012  0.0900  0.3634
# play_dist:reflex  -0.0671   0.0204  -3.2820 0.0010 -0.1071 -0.0270
# ==================================================================

# %% [markdown]
# So we don't lose a lot of Pseudo R^2 and the AIC and BIC values are lower, so let's say this model is 'better'.
#
# Let's model the `main effects` only to see if these interaction terms are even important.

# %%
l = smf.logit(
    formula=f"hit ~ play_dist + reach + magnet + reflex",
    data=attributes_with_fielding,
).fit()
print(l.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.561751
#          Iterations 5
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.027
# Dependent Variable: hit              AIC:              43151.3240
# Date:               2023-01-15 14:18 BIC:              43194.1029
# No. Observations:   38399            Log-Likelihood:   -21571.
# Df Model:           4                LL-Null:          -22176.
# Df Residuals:       38394            LLR p-value:      9.1734e-261
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     5.0000
# -------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept     -0.9101    0.0416  -21.8530  0.0000  -0.9917  -0.8285
# play_dist      0.1412    0.0061   23.0238  0.0000   0.1291   0.1532
# reach         -0.0008    0.0423   -0.0179  0.9857  -0.0836   0.0821
# magnet        -1.0615    0.0407  -26.0842  0.0000  -1.1412  -0.9817
# reflex         0.0345    0.0384    0.8973  0.3696  -0.0408   0.1098
# ==================================================================

# %% [markdown]
# This is worse: we go down in Psuedo R^2 and up in AIC and BIC, so the interaction model is probably closer to reality.

# %% [markdown]
# ### More Weird Plays Analysis
#
# Let's see if the false positive on `hustle` is because the players who did `weird plays` all have a significant hustle stat.

# %%
attributes_with_fielding_weird = (
    fielding_locs[weird_fielding_locs]
    .merge(attributes_raw, on="Name")
    .rename(columns={"play_dist manhattan": "play_dist"})
)

# %%
attributes_with_fielding_weird.drop_duplicates("Name")[player_attributes].describe().T.sort_values("mean", ascending=False)
# Out:
#          count      mean       std   min     25%    50%     75%   max
# hustle    18.0  0.629444  0.312136  0.08  0.3150  0.690  0.9125  1.00
# survive   18.0  0.599444  0.280891  0.07  0.4300  0.595  0.8750  0.96
# thwack    18.0  0.570000  0.254003  0.05  0.4100  0.615  0.7400  0.97
# fero      18.0  0.545556  0.267213  0.12  0.3050  0.535  0.7950  0.92
# drama     18.0  0.533333  0.226845  0.26  0.3675  0.440  0.7350  0.99
# control   18.0  0.520000  0.316581  0.02  0.2525  0.535  0.8025  0.99
# thrive    18.0  0.495556  0.316418  0.05  0.1850  0.545  0.7350  0.98
# magnet    18.0  0.486667  0.301545  0.09  0.2175  0.530  0.6325  1.00
# sight     18.0  0.483889  0.245312  0.11  0.2650  0.475  0.6825  0.90
# reach     18.0  0.468889  0.252817  0.07  0.2800  0.465  0.6850  0.96
# reflex    18.0  0.466667  0.329063  0.02  0.1925  0.310  0.7775  0.93
# stealth   18.0  0.458333  0.314049  0.04  0.1400  0.540  0.7100  0.90
# guile     18.0  0.435000  0.334633  0.01  0.1875  0.365  0.6750  1.00
# dodge     18.0  0.430556  0.289350  0.00  0.2825  0.325  0.6750  0.91
# stuff     18.0  0.390000  0.302869  0.02  0.1750  0.270  0.5875  0.99

# %% [markdown]
# Well, hot darn. Players who made weird plays have a mean `hustle` of `.62`, so that would have explained the previous relationship we saw with hustle being significant in the interaction with `play_dist`.
